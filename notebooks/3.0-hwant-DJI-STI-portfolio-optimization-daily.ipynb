# %%
import pandas as pd
from pypfopt.efficient_frontier import EfficientFrontier
from pypfopt import risk_models
from pypfopt import expected_returns

import numpy as np

# %%
import os
dirname = os.getcwd()
parent_dirname = os.path.dirname(dirname)

# %%
# Read in price data
df = pd.read_csv(os.path.join(parent_dirname, 'data/raw/dji_sti_adj_price_daily.csv'),
                 parse_dates=True, 
                 index_col="Date")

# %%
# Calculate daily returns
# ret = (df - df.shift()) / df.shift()
ret = np.log(df) - np.log(df.shift())
# do not drop NA

# %%
# remove STI
# ret = ret.drop('^STI', axis=1)

# %%
# Calculate mean and covariance of daily log return
mu = ret.mean()
S = ret.cov()

# %%
# Plot the portfolios
plot_df = pd.DataFrame({'mu':mu, 'S':np.sqrt(np.diag(S))})

# %%
plot_df
# Out:
#                mu         S
# A17U.SI  0.000740  0.008416
# AAPL     0.002131  0.017604
# AXP      0.000895  0.011899
# BA       0.000402  0.018953
# BN4.SI   0.000766  0.013336
# BS6.SI   0.000189  0.025490
# C07.SI  -0.000327  0.014250
# C09.SI   0.001116  0.012769
# C31.SI   0.001179  0.009752
# C38U.SI  0.000318  0.010422
# C52.SI   0.000784  0.012428
# C61U.SI  0.000712  0.010273
# C6L.SI   0.000037  0.007828
# CAT      0.000737  0.017668
# CSCO     0.000210  0.016099
# CVX      0.000351  0.012705
# D01.SI  -0.001911  0.017664
# D05.SI   0.000595  0.009551
# DIS      0.001169  0.014762
# DOW      0.000595  0.021425
# E5H.SI  -0.000503  0.027872
# F34.SI   0.001363  0.011703
# G13.SI  -0.000126  0.012208
# GS       0.001250  0.015674
# H78.SI  -0.000629  0.014830
# HD       0.001078  0.012355
# IBM      0.000767  0.013467
# INTC     0.000918  0.017875
# J36.SI  -0.000767  0.015676
# J37.SI  -0.000526  0.014673
# JNJ      0.000473  0.011052
# JPM      0.001416  0.012312
# KO       0.000599  0.011130
# MCD      0.000441  0.009941
# MMM     -0.000400  0.016493
# MRK      0.000788  0.012075
# MSFT     0.001686  0.013723
# N2IU.SI  0.001214  0.011992
# NKE      0.001384  0.015198
# O39.SI   0.000134  0.008429
# PFE     -0.000324  0.012558
# PG       0.001319  0.010959
# S58.SI   0.000558  0.009972
# S63.SI  -0.000016  0.010633
# S68.SI   0.001092  0.010259
# T39.SI  -0.000582  0.015082
# TRV      0.000584  0.011182
# U11.SI   0.000440  0.009425
# U14.SI   0.001219  0.011434
# U96.SI  -0.000068  0.016396
# UNH      0.000471  0.016402
# UTX      0.001116  0.014039
# V        0.001397  0.012547
# V03.SI   0.000530  0.019703
# VZ       0.000499  0.010394
# WBA     -0.000977  0.018219
# WMT      0.001207  0.009948
# XOM     -0.000082  0.012530
# Y92.SI   0.004856  0.034498
# Z74.SI   0.000803  0.009766

# %%
plot_df.plot.scatter(x='S', y='mu')

# %%
# Calculate correlation
r = ret.corr()
# r

# %%
# Portfolio analysis
ef = EfficientFrontier(mu, S, weight_bounds=(0, 1))

# %%
# optimize wrt max sharpe ratio
raw_weights = ef.max_sharpe(risk_free_rate=0.02)
cleaned_weights = ef.clean_weights()

# %%
# View clean weights
cleaned_weights
# Out:
# {'A17U.SI': 0.0,
#  'AAPL': 1.0,
#  'AXP': 0.0,
#  'BA': 0.0,
#  'BN4.SI': 0.0,
#  'BS6.SI': 0.0,
#  'C07.SI': 0.0,
#  'C09.SI': 0.0,
#  'C31.SI': 0.0,
#  'C38U.SI': 0.0,
#  'C52.SI': 0.0,
#  'C61U.SI': 0.0,
#  'C6L.SI': 0.0,
#  'CAT': 0.0,
#  'CSCO': 0.0,
#  'CVX': 0.0,
#  'D01.SI': 0.0,
#  'D05.SI': 0.0,
#  'DIS': 0.0,
#  'DOW': 0.0,
#  'E5H.SI': 0.0,
#  'F34.SI': 0.0,
#  'G13.SI': 0.0,
#  'GS': 0.0,
#  'H78.SI': 0.0,
#  'HD': 0.0,
#  'IBM': 0.0,
#  'INTC': 0.0,
#  'J36.SI': 0.0,
#  'J37.SI': 0.0,
#  'JNJ': 0.0,
#  'JPM': 0.0,
#  'KO': 0.0,
#  'MCD': 0.0,
#  'MMM': 0.0,
#  'MRK': 0.0,
#  'MSFT': 0.0,
#  'N2IU.SI': 0.0,
#  'NKE': 0.0,
#  'O39.SI': 0.0,
#  'PFE': 0.0,
#  'PG': 0.0,
#  'S58.SI': 0.0,
#  'S63.SI': 0.0,
#  'S68.SI': 0.0,
#  'T39.SI': 0.0,
#  'TRV': 0.0,
#  'U11.SI': 0.0,
#  'U14.SI': 0.0,
#  'U96.SI': 0.0,
#  'UNH': 0.0,
#  'UTX': 0.0,
#  'V': 0.0,
#  'V03.SI': 0.0,
#  'VZ': 0.0,
#  'WBA': 0.0,
#  'WMT': 0.0,
#  'XOM': 0.0,
#  'Y92.SI': 0.0,
#  'Z74.SI': 0.0}

# %%
ef.portfolio_performance(verbose=True)
# Out:
# Expected annual return: 0.2%
# Annual volatility: 1.8%
# Sharpe Ratio: -1.02
# (0.0021309165498527116, 0.017603622276997927, -1.0150799175858385)

# %%
# how much of each stock to buy?
capital = 10000

from pypfopt.discrete_allocation import DiscreteAllocation, get_latest_prices

latest_prices = get_latest_prices(df)

da = DiscreteAllocation(raw_weights, latest_prices, total_portfolio_value=capital)
allocation, leftover = da.lp_portfolio()
print("Discrete allocation:", allocation)
print("Funds remaining: ${:.2f}".format(leftover))
# Out:
# 59 out of 60 tickers were removed
# Discrete allocation: {'AAPL': 36}
# Funds remaining: $94.60
